# %%
wal = pd.read_csv('train.csv')
wal = wal.sort_values(by=['store_nbr'], ascending=True).head(1000)
wal
# Out:
#                date  store_nbr  item_nbr  units
# 0        2012-01-01          1         1      0
# 517773   2012-04-16          1        70      0
# 517774   2012-04-16          1        71      0
# 517775   2012-04-16          1        72      0
# 517776   2012-04-16          1        73      0
# 517777   2012-04-16          1        74      0
# 517778   2012-04-16          1        75      0
# 517779   2012-04-16          1        76      0
# 517780   2012-04-16          1        77      0
# 517781   2012-04-16          1        78      0
# 517782   2012-04-16          1        79      0
# 517783   2012-04-16          1        80      0
# 517784   2012-04-16          1        81      0
# 517785   2012-04-16          1        82      0
# 517786   2012-04-16          1        83      0
# 517787   2012-04-16          1        84      0
# 517788   2012-04-16          1        85      0
# 517789   2012-04-16          1        86      0
# 517790   2012-04-16          1        87      0
# ...

# %%
sns.pairplot(wal, x_vars=["store_nbr", "item_nbr"], y_vars=["units"],kind="reg")

# %%
sns.jointplot("station_nbr", "store_nbr", data=wal4, kind="reg")

# %%
wal2 = pd.read_csv('test.csv')
wal2.head()
# Out:
#          date  store_nbr  item_nbr
# 0  2013-04-01          2         1
# 1  2013-04-01          2         2
# 2  2013-04-01          2         3
# 3  2013-04-01          2         4
# 4  2013-04-01          2         5

# %%
wal3 = pd.read_csv('weather.csv')
wal3.head(20)
# Out:
#     station_nbr        date tmax tmin tavg depart dewpoint wetbulb heat cool  \
# 0             1  2012-01-01   52   31   42      M       36      40   23    0
# 1             2  2012-01-01   48   33   41     16       37      39   24    0
# 2             3  2012-01-01   55   34   45      9       24      36   20    0
# 3             4  2012-01-01   63   47   55      4       28      43   10    0
# 4             6  2012-01-01   63   34   49      0       31      43   16    0
# 5             7  2012-01-01   50   33   42      M       26      35   23    0
# 6             8  2012-01-01   66   45    M      M       34      46    M    M
# 7             9  2012-01-01   34   19   27      M       17      23   38    0
# 8            10  2012-01-01   73   53   63      M       55      58    2    0
# 9            11  2012-01-01   72   48   60      7       54      56    5    0
# 10           12  2012-01-01   72   48   60      M       54      57    5    0
# ...

# %%
wal4 = pd.read_csv('key.csv')
wal4.sort_values(by=['station_nbr']).reset_index(drop=True)
# Out:
#     store_nbr  station_nbr
# 0           1            1
# 1          16            2
# 2          29            3
# 3          21            3
# 4          33            3
# 5           8            4
# 6          35            5
# 7          13            6
# 8           7            6
# 9           3            7
# 10         28            7
# 11         20            7
# 12         39            8
# 13         24            9
# 14          4            9
# 15         11           10
# 16         27           10
# 17         22           10
# 18         43           11
# 19         12           11
# 20         44           12
# 21         41           12
# 22          5           12
# 23         10           12
# 24         40           13
# 25         25           13
# 26         15           13
# 27         37           13
# 28         32           13
# 29         42           14
# 30          2           14
# 31         38           14
# 32          6           14
# ...

# %%
wal4.plot.scatter(x='store_nbr', y='station_nbr')
plt.show()

# %%
sns.jointplot("station_nbr", "store_nbr", data=wal4, kind="kde")

# %%
sns.jointplot("station_nbr", "store_nbr", data=wal4, kind="reg")

# %%
wal5 = pd.read_csv('sampleSubmission.csv')
wal5.head(20)
# Out:
#                  id  units
# 0    2_1_2013-04-01      0
# 1    2_2_2013-04-01      0
# 2    2_3_2013-04-01      0
# 3    2_4_2013-04-01      0
# 4    2_5_2013-04-01      0
# 5    2_6_2013-04-01      0
# 6    2_7_2013-04-01      0
# 7    2_8_2013-04-01      0
# 8    2_9_2013-04-01      0
# 9   2_10_2013-04-01      0
# 10  2_11_2013-04-01      0
# 11  2_12_2013-04-01      0
# 12  2_13_2013-04-01      0
# 13  2_14_2013-04-01      0
# 14  2_15_2013-04-01      0
# 15  2_16_2013-04-01      0
# 16  2_17_2013-04-01      0
# 17  2_18_2013-04-01      0
# 18  2_19_2013-04-01      0
# 19  2_20_2013-04-01      0

# %%
len(wal5)
# Out:
# 526917

# %%
import time
import sys
import numpy as np
import pandas as pd
from sklearn.cross_validation import train_test_split, KFold
import multiprocessing
import os
from tqdm import tqdm
from scipy import sparse
# Out:
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
from scipy.stats import spearmanr, pearsonr
from sklearn import ensemble

# %%
import datetime as dt
from datetime import date
import calendar
from calendar import weekday, day_name

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
import scipy as sp
# Out:
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
from patsy import dmatrix
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
import scipy as sp
from sklearn.datasets import make_regression

# %%
def get_holidays(fpath):
    
    f = open(fpath)
    lines = f.readlines()
    lines = [line.split(" ")[:3] for line in lines]
    lines = ["{} {} {}".format(line[0], line[1], line[2]) for line in lines]
    lines = pd.to_datetime(lines)
    return pd.DataFrame({"date2":lines})

# %%
def get_holiday_names(fpath):
    # holiday_names are holidays + around Black Fridays
    
    f = open(fpath)
    lines = f.readlines()
    lines = [line.strip().split(" ")[:4] for line in lines]
    lines_dt = ["{} {} {}".format(line[0], line[1], line[2]) for line in lines]
    lines_dt = pd.to_datetime(lines_dt)
    lines_hol = [line[3] for line in lines]
    return pd.DataFrame({"date2":lines_dt, "holiday_name":lines_hol})

# %%
def preprocess(_df):
    
    df = _df.copy()
    
    # date
    df['date2'] = pd.to_datetime(df['date'])
    
    # weekday
    df['weekday'] = df[['date2']].apply(lambda x: dt.datetime.strftime(x['date2'], '%a'), axis=1)
    # 김태형) 더미변수로 바꿔주기 위해 문자열로 생성

    #df['weekday'] = df.date2.dt.weekday
    df['is_weekend'] = df.date2.dt.weekday.isin([5,6])
    df['is_holiday'] = df.date2.isin(holidays.date2)
    df['is_holiday_weekday'] = df.is_holiday & (df.is_weekend == False)
    df['is_holiday_weekend'] = df.is_holiday &  df.is_weekend

    # bool to int (maybe no meaning)
    df.is_weekend = np.where(df.is_weekend, 1, 0)
    df.is_holiday = np.where(df.is_holiday, 1, 0)
    df.is_holiday_weekday = np.where(df.is_holiday_weekday, 1, 0)
    df.is_holiday_weekend = np.where(df.is_holiday_weekend, 1, 0)
    
    # day, month, year
    df['day'] = df.date2.dt.day
    df['month'] = df.date2.dt.month
    df['year'] = df.date2.dt.year
    
    # around BlackFriday
    df = pd.merge(df, holiday_names, on='date2', how = 'left')
    df.loc[df.holiday_name.isnull(), "holiday_name"] = ""

    around_BlackFriday = ["BlackFridayM3", "BlackFridayM2", "ThanksgivingDay", "BlackFriday",
                          "BlackFriday1", "BlackFriday2", "BlackFriday3"]
    df["around_BlackFriday"] = np.where(df.holiday_name.isin(around_BlackFriday), 
                                        df.holiday_name, "Else")

    return df

# %%
train_file = pd.read_csv("Data/train.csv", sep=',')
train_file
# Out:
#                date  store_nbr  item_nbr  units
# 0        2012-01-01          1         1      0
# 1        2012-01-01          1         2      0
# 2        2012-01-01          1         3      0
# 3        2012-01-01          1         4      0
# 4        2012-01-01          1         5      0
# 5        2012-01-01          1         6      0
# 6        2012-01-01          1         7      0
# 7        2012-01-01          1         8      0
# 8        2012-01-01          1         9     29
# 9        2012-01-01          1        10      0
# 10       2012-01-01          1        11      0
# 11       2012-01-01          1        12      0
# 12       2012-01-01          1        13      0
# 20                1           1                   0                   1    1
# 21                1           1                   0                   1    1
# 22                1           1                   0                   1    1
# 23                1           1                   0                   1    1
# 24                1           1                   0                   1    1
# 25                1           1                   0                   1    1
# 26                1           1                   0                   1    1
# 27                1           1                   0                   1    1
# 28                1           1                   0                   1    1
# 29                1           1                   0                   1    1
# ...             ...         ...                 ...                 ...  ...
# 4617570           0           1                   1                   0   31
# 4617571           0           1                   1                   0   31
# 4617572           0           1                   1                   0   31
# 4617573           0           1                   1                   0   31
# 4617574           0           1                   1                   0   31
# 4617575           0           1                   1                   0   31
# 4617576           0           1                   1                   0   31
# 4617577           0           1                   1                   0   31
# 4617578           0           1                   1                   0   31
# 4617579           0           1                   1                   0   31
# 4617580           0           1                   1                   0   31
# 4617581           0           1                   1                   0   31
# 4617582           0           1                   1                   0   31
# 4617583           0           1                   1                   0   31
# 4617584           0           1                   1                   0   31
# 4617585           0           1                   1                   0   31
# 4617586           0           1                   1                   0   31
# 4617587           0           1                   1                   0   31
# 4617588           0           1                   1                   0   31
# 4617589           0           1                   1                   0   31
# 4617590           0           1                   1                   0   31
# 4617591           0           1                   1                   0   31
# 4617592           0           1                   1                   0   31
# 4617593           0           1                   1                   0   31
# 4617594           0           1                   1                   0   31
# 4617595           0           1                   1                   0   31
# 4617596           0           1                   1                   0   31
# 4617597           0           1                   1                   0   31
# 4617598           0           1                   1                   0   31
# 4617599           0           1                   1                   0   31
#
#          month  year holiday_name around_BlackFriday
# 0            1  2012  NewYearsDay               Else
# 1            1  2012  NewYearsDay               Else
# 2            1  2012  NewYearsDay               Else
# 3            1  2012  NewYearsDay               Else
# 4            1  2012  NewYearsDay               Else
# 5            1  2012  NewYearsDay               Else
# 6            1  2012  NewYearsDay               Else
# 7            1  2012  NewYearsDay               Else
# 8            1  2012  NewYearsDay               Else
# 9            1  2012  NewYearsDay               Else
# 10           1  2012  NewYearsDay               Else
# 11           1  2012  NewYearsDay               Else
# 12           1  2012  NewYearsDay               Else
# 13           1  2012  NewYearsDay               Else
# 14           1  2012  NewYearsDay               Else
# 15           1  2012  NewYearsDay               Else
# 16           1  2012  NewYearsDay               Else
# 17           1  2012  NewYearsDay               Else
# 18           1  2012  NewYearsDay               Else
# 19           1  2012  NewYearsDay               Else
# 20           1  2012  NewYearsDay               Else
# 21           1  2012  NewYearsDay               Else
# 22           1  2012  NewYearsDay               Else
# 23           1  2012  NewYearsDay               Else
# 24           1  2012  NewYearsDay               Else
# 25           1  2012  NewYearsDay               Else
# 26           1  2012  NewYearsDay               Else
# 27           1  2012  NewYearsDay               Else
# 28           1  2012  NewYearsDay               Else
# 29           1  2012  NewYearsDay               Else
# ...        ...   ...          ...                ...
# 4617570     10  2014    Halloween               Else
# 4617571     10  2014    Halloween               Else
# 4617572     10  2014    Halloween               Else
# 4617573     10  2014    Halloween               Else
# 4617574     10  2014    Halloween               Else
# 4617575     10  2014    Halloween               Else
# 4617576     10  2014    Halloween               Else
# 4617577     10  2014    Halloween               Else
# 4617578     10  2014    Halloween               Else
# 4617579     10  2014    Halloween               Else
# 4617580     10  2014    Halloween               Else
# 4617581     10  2014    Halloween               Else
# 4617582     10  2014    Halloween               Else
# 4617583     10  2014    Halloween               Else
# 4617584     10  2014    Halloween               Else
# 4617585     10  2014    Halloween               Else
# 4617586     10  2014    Halloween               Else
# 4617587     10  2014    Halloween               Else
# 4617588     10  2014    Halloween               Else
# 4617589     10  2014    Halloween               Else
# 4617590     10  2014    Halloween               Else
# 4617591     10  2014    Halloween               Else
# 4617592     10  2014    Halloween               Else
# 4617593     10  2014    Halloween               Else
# 4617594     10  2014    Halloween               Else
# 4617595     10  2014    Halloween               Else
# 4617596     10  2014    Halloween               Else
# 4617597     10  2014    Halloween               Else
# 4617598     10  2014    Halloween               Else
# 4617599     10  2014    Halloween               Else
#
# [4617600 rows x 15 columns]

# %%
key_file = pd.read_csv("Data/key.csv", sep=',')
key_file
# Out:
#     store_nbr  station_nbr
# 0           1            1
# 1           2           14
# 2           3            7
# 3           4            9
# 4           5           12
# 5           6           14
# 6           7            6
# 7           8            4
# 8           9           17
# 9          10           12
# 10         11           10
# 11         12           11
# 12         13            6
# 13         14           16
# 14         15           13
# 15         16            2
# 16         17           20
# 17         18           17
# 18         19           15
# 19         20            7
# 20         21            3
# 21         22           10
# 22         23           17
# 23         24            9
# 24         25           13
# 25         26           17
# 26         27           10
# 27         28            7
# 28         29            3
# 29         30           19
# 30         31           17
# 31         32           13
# 32         33            3
# 33         34           17
# 34         35            5
# 35         36           18
# 36         37           13
# 37         38           14
# 38         39            8
# 39         40           13
# 40         41           12
# 41         42           14
# 42         43           11
# 43         44           12
# 44         45           16

# %%
holidays = get_holidays("holidays.txt")
holiday_names = get_holiday_names("holiday_names.txt")

# %%
holidays
# Out:
#         date2
# 0  2012-01-01
# 1  2012-01-02
# 2  2012-01-16
# 3  2012-02-14
# 4  2012-02-20
# 5  2012-04-08
# 6  2012-05-13
# 7  2012-05-28
# 8  2012-06-17
# 9  2012-07-04
# 10 2012-09-03
# 11 2012-10-08
# 12 2012-10-31
# 13 2012-11-06
# 14 2012-11-11
# 15 2012-11-12
# 16 2012-11-22
# 17 2012-12-24
# 18 2012-12-25
# 19 2012-12-31
# 20 2013-01-01
# 21 2013-01-21
# 22 2013-02-14
# 23 2013-02-18
# 24 2013-03-31
# 25 2013-05-12
# 26 2013-05-27
# 27 2013-06-16
# 28 2013-07-04
# 29 2013-09-02
# 30 2013-10-14
# 31 2013-10-31
# 32 2013-11-11
# 33 2013-11-28
# 34 2013-12-24
# 35 2013-12-25
# 36 2013-12-31
# 37 2014-01-01
# 38 2014-01-20
# 39 2014-02-14
# 40 2014-02-17
# 41 2014-04-13
# 42 2014-04-20
# 43 2014-05-11
# 44 2014-05-26
# 45 2014-06-15
# 46 2014-07-04
# 47 2014-09-01
# 48 2014-10-13
# 49 2014-10-31
# 50 2014-11-11
# 51 2014-11-27
# 52 2014-12-24
# 53 2014-12-25
# 54 2014-12-31

# %%
holiday_names
# Out:
#         date2         holiday_name
# 0  2012-01-01          NewYearsDay
# 1  2012-01-16  MartinLutherKingDay
# 2  2012-02-14        ValentinesDay
# 3  2012-02-20        PresidentsDay
# 4  2012-04-08         EasterSunday
# 5  2012-05-13           MothersDay
# 6  2012-05-28          MemorialDay
# 7  2012-06-17           FathersDay
# 8  2012-07-04      IndependenceDay
# 9  2012-09-03             LaborDay
# 10 2012-10-08          ColumbusDay
# 11 2012-10-31            Halloween
# 12 2012-11-11          VeteransDay
# 13 2012-11-20        BlackFridayM3
# 14 2012-11-21        BlackFridayM2
# 15 2012-11-22      ThanksgivingDay
# 16 2012-11-23          BlackFriday
# 17 2012-11-24         BlackFriday1
# 18 2012-11-25         BlackFriday2
# 19 2012-11-26         BlackFriday3
# 20 2012-12-24         ChristmasEve
# 21 2012-12-25         ChristmasDay
# 22 2012-12-31          NewYearsEve
# 23 2013-01-01          NewYearsDay
# 24 2013-01-21  MartinLutherKingDay
# 25 2013-02-14        ValentinesDay
# 26 2013-02-18        PresidentsDay
# 27 2013-03-31         EasterSunday
# 28 2013-05-12           MothersDay
# 29 2013-05-27          MemorialDay
# 30 2013-06-16           FathersDay
# 31 2013-07-04      IndependenceDay
# 32 2013-09-02             LaborDay
# 33 2013-10-14          ColumbusDay
# 34 2013-10-31            Halloween
# 35 2013-11-11          VeteransDay
# 36 2013-11-26        BlackFridayM3
# 37 2013-11-27        BlackFridayM2
# 38 2013-11-28      ThanksgivingDay
# 39 2013-11-29          BlackFriday
# 40 2013-11-30         BlackFriday1
# 41 2013-12-01         BlackFriday2
# 42 2013-12-02         BlackFriday3
# 43 2013-12-24         ChristmasEve
# 44 2013-12-25         ChristmasDay
# 45 2013-12-31          NewYearsEve
# 46 2014-01-01          NewYearsDay
# 47 2014-01-20  MartinLutherKingDay
# 48 2014-02-14        ValentinesDay
# 49 2014-02-17        PresidentsDay
# 50 2014-04-20         EasterSunday
# 51 2014-05-11           MothersDay
# 52 2014-05-26          MemorialDay
# 53 2014-06-15           FathersDay
# 54 2014-07-04      IndependenceDay
# 55 2014-09-01             LaborDay
# 56 2014-10-13          ColumbusDay
# 57 2014-10-31            Halloween

# %%
result = pd.merge(train_file, key_file, left_on='store_nbr', right_on='store_nbr', how='outer')
result
# Out:
#                date  store_nbr  item_nbr  units      date2 weekday  \
# 0        2012-01-01          1         1      0 2012-01-01     Sun
# 1        2012-01-01          1         2      0 2012-01-01     Sun
# 2        2012-01-01          1         3      0 2012-01-01     Sun
# 3        2012-01-01          1         4      0 2012-01-01     Sun
# 4        2012-01-01          1         5      0 2012-01-01     Sun
# 5        2012-01-01          1         6      0 2012-01-01     Sun
# 6        2012-01-01          1         7      0 2012-01-01     Sun
# 7        2012-01-01          1         8      0 2012-01-01     Sun
# 8        2012-01-01          1         9     29 2012-01-01     Sun
# 9        2012-01-01          1        10      0 2012-01-01     Sun
# 10       2012-01-01          1        11      0 2012-01-01     Sun
# 11       2012-01-01          1        12      0 2012-01-01     Sun
# 12       2012-01-01          1        13      0 2012-01-01     Sun
# 13       2012-01-01          1        14      0 2012-01-01     Sun
# 14       2012-01-01          1        15      0 2012-01-01     Sun
# 10                1           1                   0                   1    1
# 11                1           1                   0                   1    1
# 12                1           1                   0                   1    1
# 13                1           1                   0                   1    1
# 14                1           1                   0                   1    1
# 15                1           1                   0                   1    1
# 16                1           1                   0                   1    1
# 17                1           1                   0                   1    1
# 18                1           1                   0                   1    1
# 19                1           1                   0                   1    1
# 20                1           1                   0                   1    1
# 21                1           1                   0                   1    1
# 22                1           1                   0                   1    1
# 23                1           1                   0                   1    1
# 24                1           1                   0                   1    1
# 25                1           1                   0                   1    1
# 26                1           1                   0                   1    1
# 27                1           1                   0                   1    1
# 28                1           1                   0                   1    1
# 29                1           1                   0                   1    1
# ...             ...         ...                 ...                 ...  ...
# 4617570           0           1                   1                   0   31
# 4617571           0           1                   1                   0   31
# 4617572           0           1                   1                   0   31
# 4617573           0           1                   1                   0   31
# 4617574           0           1                   1                   0   31
# 4617575           0           1                   1                   0   31
# 4617576           0           1                   1                   0   31
# 4617577           0           1                   1                   0   31
# 4617578           0           1                   1                   0   31
# 4617579           0           1                   1                   0   31
# 4617580           0           1                   1                   0   31
# 4617581           0           1                   1                   0   31
# 4617582           0           1                   1                   0   31
# 4617583           0           1                   1                   0   31
# 4617584           0           1                   1                   0   31
# 4617585           0           1                   1                   0   31
# 4617586           0           1                   1                   0   31
# 4617587           0           1                   1                   0   31
# 4617588           0           1                   1                   0   31
# 4617589           0           1                   1                   0   31
# 4617590           0           1                   1                   0   31
# 4617591           0           1                   1                   0   31
# 4617592           0           1                   1                   0   31
# 4617593           0           1                   1                   0   31
# 4617594           0           1                   1                   0   31
# 4617595           0           1                   1                   0   31
# 4617596           0           1                   1                   0   31
# 4617597           0           1                   1                   0   31
# 4617598           0           1                   1                   0   31
# 4617599           0           1                   1                   0   31
#
#          month  year holiday_name around_BlackFriday  station_nbr
# 0            1  2012  NewYearsDay               Else            1
# 1            1  2012  NewYearsDay               Else            1
# 2            1  2012  NewYearsDay               Else            1
# 3            1  2012  NewYearsDay               Else            1
# 4            1  2012  NewYearsDay               Else            1
# 5            1  2012  NewYearsDay               Else            1
# 6            1  2012  NewYearsDay               Else            1
# 7            1  2012  NewYearsDay               Else            1
# 8            1  2012  NewYearsDay               Else            1
# 9            1  2012  NewYearsDay               Else            1
# 10           1  2012  NewYearsDay               Else            1
# 11           1  2012  NewYearsDay               Else            1
# 12           1  2012  NewYearsDay               Else            1
# 13           1  2012  NewYearsDay               Else            1
# 14           1  2012  NewYearsDay               Else            1
# 15           1  2012  NewYearsDay               Else            1
# 16           1  2012  NewYearsDay               Else            1
# 17           1  2012  NewYearsDay               Else            1
# 18           1  2012  NewYearsDay               Else            1
# 19           1  2012  NewYearsDay               Else            1
# 20           1  2012  NewYearsDay               Else            1
# 21           1  2012  NewYearsDay               Else            1
# 22           1  2012  NewYearsDay               Else            1
# 23           1  2012  NewYearsDay               Else            1
# 24           1  2012  NewYearsDay               Else            1
# 25           1  2012  NewYearsDay               Else            1
# 26           1  2012  NewYearsDay               Else            1
# 27           1  2012  NewYearsDay               Else            1
# 28           1  2012  NewYearsDay               Else            1
# 29           1  2012  NewYearsDay               Else            1
# ...        ...   ...          ...                ...          ...
# 4617570     10  2014    Halloween               Else            5
# 4617571     10  2014    Halloween               Else            5
# 4617572     10  2014    Halloween               Else            5
# 4617573     10  2014    Halloween               Else            5
# 4617574     10  2014    Halloween               Else            5
# 4617575     10  2014    Halloween               Else            5
# 4617576     10  2014    Halloween               Else            5
# 4617577     10  2014    Halloween               Else            5
# 4617578     10  2014    Halloween               Else            5
# 4617579     10  2014    Halloween               Else            5
# 4617580     10  2014    Halloween               Else            5
# 4617581     10  2014    Halloween               Else            5
# 4617582     10  2014    Halloween               Else            5
# 4617583     10  2014    Halloween               Else            5
# 4617584     10  2014    Halloween               Else            5
# 4617585     10  2014    Halloween               Else            5
# 4617586     10  2014    Halloween               Else            5
# 4617587     10  2014    Halloween               Else            5
# 4617588     10  2014    Halloween               Else            5
# 4617589     10  2014    Halloween               Else            5
# 4617590     10  2014    Halloween               Else            5
# 4617591     10  2014    Halloween               Else            5
# 4617592     10  2014    Halloween               Else            5
# 4617593     10  2014    Halloween               Else            5
# 4617594     10  2014    Halloween               Else            5
# 4617595     10  2014    Halloween               Else            5
# 4617596     10  2014    Halloween               Else            5
# 4617597     10  2014    Halloween               Else            5
# 4617598     10  2014    Halloween               Else            5
# 4617599     10  2014    Halloween               Else            5
#
# [4617600 rows x 16 columns]

# %%
holidays = pd.read_csv('holidays.csv', sep=',')
holidays
# Out:
#           date        day         holiday_name
# 0   2012-01-01     Sunday          NewYearsDay
# 1   2012-01-16     Monday  MartinLutherKingDay
# 2   2012-02-14    Tuesday        ValentinesDay
# 3   2012-02-20     Monday        PresidentsDay
# 4   2012-04-08     Sunday         EasterSunday
# 5   2012-05-13     Sunday           MothersDay
# 6   2012-05-28     Monday          MemorialDay
# 7   2012-06-17     Sunday           FathersDay
# 8   2012-07-04  Wednesday      IndependenceDay
# 9   2012-09-03     Monday             LaborDay
# 10  2012-10-08     Monday          ColumbusDay
# 11  2012-10-31  Wednesday            Halloween
# 12  2012-11-11     Sunday          VeteransDay
# 13  2012-11-22   Thursday      ThanksgivingDay
# 14  2012-12-24     Monday         ChristmasEve
# 15  2012-12-25    Tuesday         ChristmasDay
# 16  2012-12-31     Monday          NewYearsEve
# 17  2013-01-01    Tuesday          NewYearsDay
# 18  2013-01-21     Monday  MartinLutherKingDay
# 19  2013-02-14   Thursday        ValentinesDay
# 20  2013-02-18     Monday        PresidentsDay
# 21  2013-03-31     Sunday         EasterSunday
# 22  2013-05-12     Sunday           MothersDay
# 23  2013-05-27     Monday          MemorialDay
# 24  2013-06-16     Sunday           FathersDay
# 25  2013-07-04   Thursday      IndependenceDay
# 26  2013-09-02     Monday             LaborDay
# 27  2013-10-14     Monday          ColumbusDay
# 28  2013-10-31   Thursday            Halloween
# 29  2013-11-11     Monday          VeteransDay
# 30  2013-11-28   Thursday      ThanksgivingDay
# 31  2013-12-24    Tuesday         ChristmasEve
# 32  2013-12-25  Wednesday         ChristmasDay
# 33  2013-12-31    Tuesday          NewYearsEve
# 20514   7.0   0.0    644.0  1738.0       0.0         0.00        29.78
# 20515  26.0   0.0    624.0  1646.0       0.1         0.02        29.51
# 20516   6.0   0.0    624.0  1646.0       0.0         0.00        29.57
#
#        sealevel  resultspeed  resultdir  avgspeed
# 0         29.92          3.6       20.0       4.6
# 1         29.91          9.1       23.0      11.3
# 2         30.47          9.9       31.0      10.0
# 3         30.48          8.0       35.0       8.2
# 4         30.47         14.0       36.0      13.8
# 5         30.54         10.3       32.0      10.2
# 6         30.54         11.0       36.0      10.9
# 7         30.09         22.8       30.0      22.5
# 8         30.19          5.1       24.0       5.5
# 9         30.18          4.6       23.0       4.8
# 10        30.19          4.4       25.0       4.8
# 11        30.59          2.5       16.0       6.1
# 12        30.52         11.4       32.0      11.3
# 13        29.89          2.5       17.0       3.8
# 14        29.89          4.2       21.0       6.8
# 15        30.50          5.4       32.0       5.8
# 16        30.49          9.0       33.0       8.9
# 17        29.79         14.6       29.0      15.6
# 18        30.48         10.9       33.0      10.8
# 19        29.62          9.8       24.0      10.3
# 20        29.62         12.7       26.0      13.3
# 21        30.63          7.7       32.0       8.2
# 22        30.64          3.7       36.0       4.8
# 23        30.63          9.0        1.0       9.3
# 24        30.66          5.7       34.0       6.9
# 25        30.66          6.2       36.0       6.7
# 26        30.44         14.4       32.0      14.7
# 27        30.14         10.2       30.0      11.2
# 28        30.14         10.2       29.0      11.1
# 29        30.14         11.7       30.0      12.7
# ...         ...          ...        ...       ...
# 20487     29.94          1.6       36.0       3.4
# 20488     29.94          1.5        1.0       3.3
# 20489     30.31          4.8       13.0       6.7
# 20490     30.13          4.4       34.0      10.4
# 20491     29.94          1.7       31.0       2.7
# 20492     29.91          4.0       30.0       4.6
# 20493     30.14          2.6       32.0       5.1
# 20494     30.11          2.9       14.0       5.6
# 20495     30.08          5.5       27.0       6.0
# 20496     30.11          1.6       14.0       4.9
# 20497     30.03          5.4        4.0       5.8
# 20498     30.00          6.2        5.0       7.0
# 20499     30.36         11.1       35.0      11.5
# 20500     30.23          6.0        1.0       6.5
# 20501     30.01         10.8        5.0       6.5
# 20502     30.22         11.3       36.0      11.7
# 20503     30.37         11.0        1.0      11.6
# 20504     30.37         11.0        1.0       5.1
# 20505     30.52          8.3       36.0       8.7
# 20506     29.84          6.9       31.0       7.8
# 20507     29.85          5.3       30.0       6.1
# 20508     29.85          7.0       32.0       7.5
# 20509     30.18          6.1       17.0       7.2
# 20510     30.36         11.9        1.0      12.5
# 20511     30.03          0.3        3.0       0.6
# 20512     29.99          4.5        3.0       5.3
# 20513     30.39          9.2        1.0       9.3
# 20514     30.28         10.6       36.0      11.2
# 20515     30.24         20.4       34.0      20.9
# 20516     30.27         10.5       36.0      11.2
#
# [20517 rows x 19 columns]

# %%
all_data_result = pd.merge(result, weather_file, on=['date', 'station_nbr'], how='left')
all_data_result
# Out:
#                date  store_nbr  item_nbr  units      date2 weekday  \
# 0        2012-01-01          1         1      0 2012-01-01     Sun
# 1        2012-01-01          1         2      0 2012-01-01     Sun
# 2        2012-01-01          1         3      0 2012-01-01     Sun
...      1.0    616.0  1640.0      0.0        0.30        29.55
# 4617599    ...      1.0    616.0  1640.0      0.0        0.30        29.55
#
#          sealevel  resultspeed  resultdir  avgspeed
# 0           29.92          3.6       20.0       4.6
# 1           29.92          3.6       20.0       4.6
# 2           29.92          3.6       20.0       4.6
# 3           29.92          3.6       20.0       4.6
# 4           29.92          3.6       20.0       4.6
# 5           29.92          3.6       20.0       4.6
# 6           29.92          3.6       20.0       4.6
# 7           29.92          3.6       20.0       4.6
# 8           29.92          3.6       20.0       4.6
# 9           29.92          3.6       20.0       4.6
# 10          29.92          3.6       20.0       4.6
# 11          29.92          3.6       20.0       4.6
# 12          29.92          3.6       20.0       4.6
# 13          29.92          3.6       20.0       4.6
# 14          29.92          3.6       20.0       4.6
# 15          29.92          3.6       20.0       4.6
# 16          29.92          3.6       20.0       4.6
# 17          29.92          3.6       20.0       4.6
# 18          29.92          3.6       20.0       4.6
# 19          29.92          3.6       20.0       4.6
# 20          29.92          3.6       20.0       4.6
# 21          29.92          3.6       20.0       4.6
# 22          29.92          3.6       20.0       4.6
# 23          29.92          3.6       20.0       4.6
# 24          29.92          3.6       20.0       4.6
# 25          29.92          3.6       20.0       4.6
# 26          29.92          3.6       20.0       4.6
# 27          29.92          3.6       20.0       4.6
# 28          29.92          3.6       20.0       4.6
# 29          29.92          3.6       20.0       4.6
# ...           ...          ...        ...       ...
# 4617570     30.01         10.8        5.0       6.5
# 4617571     30.01         10.8        5.0       6.5
# 4617572     30.01         10.8        5.0       6.5
# 4617573     30.01         10.8        5.0       6.5
# 4617574     30.01         10.8        5.0       6.5
# 4617575     30.01         10.8        5.0       6.5
# 4617576     30.01         10.8        5.0       6.5
# 4617577     30.01         10.8        5.0       6.5
# 4617578     30.01         10.8        5.0       6.5
# 4617579     30.01         10.8        5.0       6.5
# 4617580     30.01         10.8        5.0       6.5
# 4617581     30.01         10.8        5.0       6.5
# 4617582     30.01         10.8        5.0       6.5
# 4617583     30.01         10.8        5.0       6.5
# 4617584     30.01         10.8        5.0       6.5
# 4617585     30.01         10.8        5.0       6.5
# 4617586     30.01         10.8        5.0       6.5
# 4617587     30.01         10.8        5.0       6.5
# 4617588     30.01         10.8        5.0       6.5
# 4617589     30.01         10.8        5.0       6.5
# 4617590     30.01         10.8        5.0       6.5
# 4617591     30.01         10.8        5.0       6.5
# 4617592     30.01         10.8        5.0       6.5
# 4617593     30.01         10.8        5.0       6.5
# 4617594     30.01         10.8        5.0       6.5
# 4617595     30.01         10.8        5.0       6.5
# 4617596     30.01         10.8        5.0       6.5
# 4617597     30.01         10.8        5.0       6.5
# 4617598     30.01         10.8        5.0       6.5
# 4617599     30.01         10.8        5.0       6.5
#
# [4617600 rows x 33 columns]

# %%
all_data_result.to_csv("another_all_train_matrix.csv", sep=',', index=None)

# %%
#여기서 부터
all_data_result = pd.read_csv('another_all_train_matrix.csv', sep=',')

# %%
# ls_store_nbr = set(all_data_result.store_nbr)
# mod = sys.modules[__name__]
# df = pd.DataFrame()
# for store_nbr in tqdm(ls_store_nbr):
#     #setattr(mod, 'store_{}'.format(store_nbr), all_data_result[all_data_result['store_nbr'] == store_nbr])
#     data = all_data_result[all_data_result['store_nbr'] == store_nbr]
#     mergedata = pd.merge(data, weather_file, on = ['date'])
#     #df = df.append(mergedata, ignore_index=True)
#     setattr(mod, 'store_{}_data'.format(store_nbr), mergedata)
#     #mergedata.to_csv("store_{}_data.csv".format(store_nbr), sep=',', index=None)
# Out:
#  56%|█████▌    | 25/45 [11:46<09:25, 28.26s/it]

# %%
# pvalue 10% 
def formulaName(df, store):
    result = ""
    _df = df
    tmpPvalue = _df['P>|t|'].astype(float)
    tmpdf = _df[tmpPvalue < 0.1]
    ls = []
    tmp_store_df = tmpdf[tmpdf['store_nbr'] == store]
    Names = tmp_store_df.Name
    i = 0
    for Name in Names:
        i += 1
        if i < len(Names):
            result += Name + " "
        else:
            result += Name
    ls.append(result)
    return ls

# 카테고리값 추가
def store_formulaList(Names):
    ls_result = []
    tmp_ls = Names
    a = ""
    for item in tmp_ls:
        i = 0
        words = item.split(" ")
        for word in words:
            i += 1
            if word.startswith("C(weekday)"):
                if a.find("C(weekday)") == -1:
                    a += "C(weekday) + "
            elif word.startswith("C(item_nbr)"):
                if a.find("C(item_ nbr)") == -1:
                    a += "C(item_nbr) + "                   
            else:
                a += word + " + "

    return a[:-3]

# 위에꺼랑 같이 추가
def convert_store_formulaList(Names):
    ls_result = []
    tmp_ls = Names
    a = ""
    for item in tmp_ls:
        i = 0
        words = item.split(" ")
        for word in words:
            i += 1
            if word.startswith("C(weekday)"):
                if a.find("C(weekday)") == -1 and a.find("weekday") == -1:
                    a += "weekday + "
            elif word.startswith("C(item_nbr)"):
                if a.find("C(item_nbr)") == -1 and a.find("item_nbr") == -1:
                    a += "item_nbr + "                   
            else:
                a += word + " + "

    return a[:-3]

# predict
def store_test_predict(data, test_data, store, formulaList, f_convertList) :
    if formulaList == None:
        model = sm.OLS.from_formula( "units ~ C(item_nbr) + C(weekday) +"
                                     "is_weekend + is_holiday_weekday + "
                                     "is_holiday_weekend + "
                                     "tmax + tmin + tavg + depart + dewpoint + wetbulb + heat + cool + sunrise + "
                                     "sunset + snowfall + preciptotal + stnpressure + sealevel + resultspeed + resultdir +"
                                     "avgspeed", data=result)
    else:
        model = sm.OLS.from_formula( "units ~ " + formulaList , data=data)

    result_fit = model.fit()
    num_attr = ['store_nbr']
    num_attr.extend(f_convertList)
    
    test_predict = test_data[num_attr]
    
    result = result_fit.predict(test_predict)
    return result

# %%
# 위에 predict랑 같은 변수 넣기
def store_storage(result, store, formulaList) :
    """
    회귀분석 결과 모음

    전역변수로 아래 데이터 프레임 선언
    result_sets = pd.DataFrame(columns = ["R square", "AIC", "BIC", "P_fstatics", "P_omnibus", "P_jb", "Cond_no"])

    Variables_name.fit() 상태로 삽입
    ex)result = model.fit() 이면
    result를 삽입    


    reason = 이전 데이터 셋에서 무엇을 변화시켰는지 적을 것.
    """    
    
    global result_sets
    result_sets = pd.DataFrame(columns = ["store_nbr", "R square", "F_statics", "Prob(F_statics)", "AIC", "BIC",
                                          "Omnibus", "P_omnibus", "P_jb", "Cond_no"])

    if formulaList == None:
        model = sm.OLS.from_formula( "units ~ C(item_nbr) + C(weekday) +"
                                     "is_weekend + is_holiday_weekday + "
                                     "is_holiday_weekend + "
                                     "tmax + tmin + tavg + depart + dewpoint + wetbulb + heat + cool + sunrise + "
                                     "sunset + snowfall + preciptotal + stnpressure + sealevel + resultspeed + resultdir +"
                                     "avgspeed", data=result)
    else:
        model = sm.OLS.from_formula( "units ~ " + formulaList , data=result)

    result = model.fit()

    summary = result.summary()
    
    t1 = summary.tables[0]
    t2 = summary.tables[1]
    t3 = summary.tables[2]
    
    r_squared = float(t1.data[0][3])
    fstatics = float(t1.data[2][3])
    p_fstatics = float(t1.data[3][3])
    AIC = float(t1.data[5][3])
    BIC = float(t1.data[6][3])
    

    omnibus = float(t3.data[0][3])
    p_omnibus = float(t3.data[1][1])
    p_jb = float(t3.data[2][3])
    con = float(t3.data[3][3])

    put = {
        "store_nbr" : store,
        "R square" : r_squared,
        "F_statics" : fstatics,
        "Prob(F_statics)" : p_fstatics,
        "AIC" : AIC,
        "BIC" : BIC,
        "Omnibus" : omnibus,
        "P_omnibus" : p_omnibus,
        "P_jb" : p_jb,
        "Cond_no" : con,  
    }
    
    result_sets.loc[len(result_sets)] = put
    
    for i in range(2, len(t2)):
        result_sets = result_sets.append({
            "store_nbr" : store,
            "Name" : t2.data[i][0],
            "std err" : t2.data[i][2],
            "t" : t2.data[i][3],
            "P>|t|" : t2.data[i][4],
            "0.025" : t2.data[i][5],
            "0.975" : t2.data[i][6],
        }, ignore_index=True)
 
    return result_sets, result

# %%
def convertList(f_name):
    result = f_name.split(" + ")
    return result

# %%
# outlier
def erase_outlier_np(result, data, category=False, dropped=False):
    """
    get the fitted model result, then erase outliers in data,
    by Fox' Outlier Recommendation.
    return arranged data, dropped data(when True)
    """

    influence = result.get_influence()

    if category:
        fox_cr = 4 / (len(data) - result.df_model + 1)
    else:
        fox_cr = 4 / (len(data) - result.df_model)

    cooks_d2, pvals = influence.cooks_distance
    idx = np.where(cooks_d2 > fox_cr)[0]

    dropped_data = data.iloc[idx]
    data = data.drop(data.index[idx])
    data.reset_index(drop=True, inplace=True)

    if dropped:

        return data, dropped_data

    return data

# %%
# 여기부턴 item별
def item_formulaName(df, item):
    result = ""
    _df = df
    tmpPvalue = _df['P>|t|'].astype(float)
    tmpdf = _df[tmpPvalue < 0.1]
    ls = []
    tmp_item_df = tmpdf[tmpdf['item_nbr'] == item]
    Names = tmp_item_df.Name
    i = 0
    for Name in Names:
        i += 1
        if i < len(Names):
            result += Name + " "
        else:
            result += Name
    ls.append(result)
    return ls

def item_formulaList(Names):
    ls_result = []
    tmp_ls = Names
    a = ""
    for item in tmp_ls:
        i = 0
        words = item.split(" ")
        for word in words:
            i += 1
            if word.startswith("C(weekday)"):
                if a.find("C(weekday)") == -1:
                    a += "C(weekday) + "
            elif word.startswith("C(store_nbr)"):
                if a.find("C(store_nbr)") == -1:
                    a += "C(store_nbr) + "
            else:
                a += word + " + "

    return a[:-3]

# %%
def item_storage(result, item, formulaList) :
    """
    회귀분석 결과 모음

    전역변수로 아래 데이터 프레임 선언
    result_sets = pd.DataFrame(columns = ["R square", "AIC", "BIC", "P_fstatics", "P_omnibus", "P_jb", "Cond_no"])

    Variables_name.fit() 상태로 삽입
    ex)result = model.fit() 이면
    result를 삽입    


    reason = 이전 데이터 셋에서 무엇을 변화시켰는지 적을 것.
    """    
    
    global result_sets
    result_sets = pd.DataFrame(columns = ["item_nbr", "R square", "F_statics", "Prob(F_statics)", "AIC", "BIC",
                                          "Omnibus", "P_omnibus", "P_jb", "Cond_no"])
                
    if formulaList == None or formulaList == '':
        model = sm.OLS.from_formula( "units ~ C(store_nbr) + C(weekday):C() +"
                                     "is_weekend + is_holiday_weekday + "
                                     "is_holiday_weekend + "
                                     "tmax + tmin + tavg + depart + dewpoint + wetbulb + heat + cool + sunrise + "
                                     "sunset + snowfall + preciptotal + stnpressure + sealevel + resultspeed + resultdir +"
                                     "avgspeed", data=result)
    else:
        model = sm.OLS.from_formula( "units ~ " + formulaList , data=result)

    result = model.fit()

    summary = result.summary()
    
    t1 = summary.tables[0]
    t2 = summary.tables[1]
    t3 = summary.tables[2]
    
    r_squared = float(t1.data[0][3])
    fstatics = float(t1.data[2][3])
    p_fstatics = float(t1.data[3][3])
    AIC = float(t1.data[5][3])
    BIC = float(t1.data[6][3])
    

    omnibus = float(t3.data[0][3])
    p_omnibus = float(t3.data[1][1])
    p_jb = float(t3.data[2][3])
    con = float(t3.data[3][3])

    put = {
        "item_nbr" : item,
        "R square" : r_squared,
        "F_statics" : fstatics,
        "Prob(F_statics)" : p_fstatics,
        "AIC" : AIC,
        "BIC" : BIC,
        "Omnibus" : omnibus,
        "P_omnibus" : p_omnibus,
        "P_jb" : p_jb,
        "Cond_no" : con,  
    }
    
    result_sets.loc[len(result_sets)] = put
    
    for i in range(2, len(t2)):
        result_sets = result_sets.append({
            "item_nbr" : item,
            "Name" : t2.data[i][0],
            "std err" : t2.data[i][2],
            "t" : t2.data[i][3],
            "P>|t|" : t2.data[i][4],
            "0.025" : t2.data[i][5],
            "0.975" : t2.data[i][6],
        }, ignore_index=True)
 
    return result_sets, result

# %%
# model2 = sm.OLS.from_formula("units ~ weekday + is_weekend +"
#                             "is_holiday +is_holiday_weekend + day +"
#                             "year +"
#                             "tmin + tavg  + wetbulb + heat+"
#                             "cool + sunrise + sunset + snowfall + preciptotal + stnpressure+"
#                             "sealevel + resultspeed + resultdir + avgspeed", data=all_data_result)
# result = model2.fit()

# num_attr = ['store_nbr', 'item_nbr', 'weekday', 'is_weekend', 
#             'is_holiday', 'is_holiday_weekend',
#             'day', 'year',
#             'tmin', 'tavg',
#             'wetbulb', 'heat', 'cool', 'sunrise', 'sunset', 'snowfall',
#             'preciptotal', 'stnpressure', 'sealevel', 'resultspeed',
#             'resultdir', 'avgspeed']

# test_predict = test_gg[num_attr]

# test = result.predict(test_predict)

# %%
#store_nbr 기준으로 OLS 분류
ls_store_nbr = set(all_data_result.store_nbr)
df = pd.DataFrame()
df_out = pd.DataFrame()
for store_nbr in tqdm(ls_store_nbr):
    data = all_data_result[all_data_result['store_nbr'] == store_nbr]
    #data = data[data['units'] > 0]
    tmp_df, result = store_storage(data, store_nbr, None)
    df = df.append(tmp_df, ignore_index=True)
    temp = erase_outlier_np(result, data)
    df_out = df_out.append(temp, ignore_index=True)
# Out:
# 100%|██████████| 45/45 [00:09<00:00,  4.59it/s]

# %%
#2차 _ 아웃라이어 제거 후 OLS 
ls_store_nbr = set(all_data_result.store_nbr)
df = pd.DataFrame()
for store_nbr in tqdm(ls_store_nbr):
    data = df_out[df_out['store_nbr'] == store_nbr]
    #data = data[data['units'] > 0]
    tmp_df, result = store_storage(data, store_nbr, None)
    df = df.append(tmp_df, ignore_index=True)
# Out:
# 100%|██████████| 45/45 [00:07<00:00,  5.99it/s]

# %%
#store_nbr 기준으로 OLS 분류 - p-value 제거 
ls_store_nbr = set(all_data_result.store_nbr)
o_df = pd.DataFrame()
test_predict = pd.DataFrame()
for store_nbr in tqdm(ls_store_nbr):
    data = df_out[df_out['store_nbr'] == store_nbr]
    test_data = test_gg[test_gg['store_nbr'] == store_nbr]
    #data = data[data['units'] > 0]
    f_list = formulaName(df, store_nbr)
    f_name = convert_store_formulaList(f_list)
    f_convertList = convertList(f_name)
    tmp_df, result = store_storage(data, store_nbr, f_name)
    tmp_predict = pd.DataFrame(data=store_test_predict(data, test_data, store_nbr, f_name, f_convertList))
    test_predict = test_predict.append(tmp_predict, ignore_index=True)
    o_df = o_df.append(tmp_df, ignore_index=True)
# Out:
#   7%|▋         | 3/45 [00:00<00:06,  6.14it/s]/usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1471: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/base/model.py:1036: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# 100%|██████████| 45/45 [00:06<00:00,  6.51it/s]

# %% [markdown]
# ## Model_store

# %%
# #store_nbr 기준으로 OLS 분류
# ls_store_nbr = set(all_data_result.store_nbr)
# df = pd.DataFrame()
# df_out = pd.DataFrame()
# for store_nbr in tqdm(ls_store_nbr):
#     data = all_data_result[all_data_result['store_nbr'] == store_nbr]
#     data = data[data['units'] > 0]
#     tmp_df, result = store_storage(data, store_nbr, None)
#     df = df.append(tmp_df, ignore_index=True)
#     temp = erase_outlier_np(result, data)
#     df_out = df_out.append(temp, ignore_index=True)
# Out:
# 100%|██████████| 45/45 [00:07<00:00,  5.66it/s]

# %%
# df.to_csv('store_units0_OLS_1차.csv', sep=',', index=None)

# %%
# #2차 _ 아웃라이어 제거
# ls_store_nbr = set(all_data_result.store_nbr)
# df = pd.DataFrame()
# for store_nbr in tqdm(ls_store_nbr):
#     data = df_out[df_out['store_nbr'] == store_nbr]
#     data = data[data['units'] > 0]
#     tmp_df, result = store_storage(data, store_nbr, None)
#     df = df.append(tmp_df, ignore_index=True)
# Out:
# 100%|██████████| 45/45 [00:05<00:00,  7.91it/s]

# %%
# df.to_csv('store_units0_OLS_2차(아웃라이어제거).csv', sep=',', index=None)

# %%
# #store_nbr 기준으로 OLS 분류 - p-value 제거
# ls_store_nbr = set(all_data_result.store_nbr)
# o_df = pd.DataFrame()
# for store_nbr in tqdm(ls_store_nbr):
#     data = df_out[df_out['store_nbr'] == store_nbr]
#     data = data[data['units'] > 0]
#     f_list = formulaName(df, store_nbr)
#     f_name = formulaList(f_list)
#     tmp_df, result = store_storage(data, store_nbr, f_name)
#     o_df = o_df.append(tmp_df, ignore_index=True)
# Out:
#  67%|██████▋   | 30/45 [00:01<00:00, 17.44it/s]/usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1471: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/base/model.py:1036: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# 100%|██████████| 45/45 [00:02<00:00, 17.69it/s]

# %%
# o_df.to_csv('store_units0_OLS_3차(p-value제거).csv', sep=',', index=None)

# %% [markdown]
# ## Model

# %%
#item_nbr 기준으로 OLS 분류
ls_item_nbr = set(all_data_result.item_nbr)
i_df = pd.DataFrame()
i_df_out = pd.DataFrame()
for item_nbr in tqdm(ls_item_nbr):
    data = all_data_result[all_data_result['item_nbr'] == item_nbr]
    data = data[data['units'] > 0]
    tmp_df, result = item_storage(data, item_nbr, None)
    i_df = i_df.append(tmp_df, ignore_index=True)
    temp = erase_outlier_np(result, data)  #아웃라이어 제거
    i_df_out = i_df_out.append(temp, ignore_index=True)
# Out:
#   0%|          | 0/111 [00:00<?, ?it/s]/usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/stats/outliers_influence.py:309: RuntimeWarning: invalid value encountered in sqrt
#   return  self.results.resid / sigma / np.sqrt(1 - hii)
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in greater
#   app.launch_new_instance()
#  85%|████████▍ | 94/111 [00:19<00:03,  4.79it/s]/usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/stats/outliers_influence.py:309: RuntimeWarning: divide by zero encountered in true_divide
#   return  self.results.resid / sigma / np.sqrt(1 - hii)
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/stats/outliers_influence.py:403: RuntimeWarning: divide by zero encountered in true_divide
#   cooks_d2 *= hii / (1 - hii)
# 100%|██████████| 111/111 [00:23<00:00,  4.79it/s]

# %%
i_df.to_csv('item_units0_OLS_1차.csv',sep=',', index=None )

# %%
#2차 _ 아웃라이어 제거
ls_item_nbr = set(all_data_result.item_nbr)
i_df = pd.DataFrame()
for item_nbr in tqdm(ls_item_nbr):
    data = i_df_out[i_df_out['item_nbr'] == item_nbr]
    data = data[data['units'] > 0]
    tmp_df, result = item_storage(data, item_nbr, None)
    i_df = i_df.append(tmp_df, ignore_index=True)
# Out:
#  91%|█████████ | 101/111 [00:13<00:01,  7.71it/s]/usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/stats.py:1390: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   "anyway, n=%i" % int(n))
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1392: RuntimeWarning: divide by zero encountered in true_divide
#   return 1 - np.divide(self.nobs - self.k_constant, self.df_resid) * (1 - self.rsquared)
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1392: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - np.divide(self.nobs - self.k_constant, self.df_resid) * (1 - self.rsquared)
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1400: RuntimeWarning: divide by zero encountered in double_scalars
#   return self.ssr/self.df_resid
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1353: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/base/model.py:1118: RuntimeWarning: invalid value encountered in multiply
#   cov_p = self.normalized_cov_params * scale
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# 100%|██████████| 111/111 [00:14<00:00,  7.77it/s]

# %%
i_df.to_csv('item_units0_OLS_2차.csv',sep=',', index=None )

# %%
#store_nbr 기준으로 OLS 분류 - p-value 제거
ls_item_nbr = set(all_data_result.item_nbr)
i_o_df = pd.DataFrame()
for item_nbr in tqdm(ls_item_nbr):
    data = i_df_out[i_df_out['item_nbr'] == item_nbr]
    data = data[data['units'] > 0]
    i_f_list = item_formulaName(i_df, item_nbr)
    i_f_name = item_formulaList(i_f_list)
    tmp_df, result = item_storage(data, item_nbr, i_f_name)
    i_o_df = i_o_df.append(tmp_df, ignore_index=True)
# Out:
#  51%|█████▏    | 57/111 [00:03<00:03, 15.74it/s]/usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1471: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/base/model.py:1036: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
#  91%|█████████ | 101/111 [00:05<00:00, 17.65it/s]/usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/stats/stats.py:1390: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   "anyway, n=%i" % int(n))
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1392: RuntimeWarning: divide by zero encountered in true_divide
#   return 1 - np.divide(self.nobs - self.k_constant, self.df_resid) * (1 - self.rsquared)
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1392: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - np.divide(self.nobs - self.k_constant, self.df_resid) * (1 - self.rsquared)
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1400: RuntimeWarning: divide by zero encountered in double_scalars
#   return self.ssr/self.df_resid
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1353: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/statsmodels/base/model.py:1118: RuntimeWarning: invalid value encountered in multiply
#   cov_p = self.normalized_cov_params * scale
# 100%|██████████| 111/111 [00:06<00:00, 17.72it/s]

# %%
i_o_df.to_csv('item_units0_OLS_3차.csv',sep=',', index=None )

# %%
test = pd.read_csv('tae/test.csv')
weather = pd.read_csv('tae/weather_processed.csv')
key = pd.read_csv('tae/key.csv')
holidays = get_holidays("tae/walmart_holidays.txt")
holiday_names = get_holiday_names("tae/walmart_holiday_names.txt")
test_key = pd.merge(test, key, on=['store_nbr'], how='left')

test_merge =  pd.merge(test_key, weather, on=['date', 'station_nbr'], how='left')
test_gg = preprocess(test_merge)

# %%
test_gg.tail()
# Out:
#               date  store_nbr  item_nbr  station_nbr  tmax  tmin  tavg  \
# 526912  2014-10-26         45       107           16  58.0  41.0  50.0
# 526913  2014-10-26         45       108           16  58.0  41.0  50.0
# 526914  2014-10-26         45       109           16  58.0  41.0  50.0
# 526915  2014-10-26         45       110           16  58.0  41.0  50.0
# 526916  2014-10-26         45       111           16  58.0  41.0  50.0
#
#         depart  dewpoint  wetbulb         ...          weekday  is_weekend  \
# 526912     4.0      39.0     46.0         ...              Sun           1
# 526913     4.0      39.0     46.0         ...              Sun           1
# 526914     4.0      39.0     46.0         ...              Sun           1
# 526915     4.0      39.0     46.0         ...              Sun           1
# 526916     4.0      39.0     46.0         ...              Sun           1
#
#         is_holiday  is_holiday_weekday  is_holiday_weekend  day  month  year  \
# 526912           0                   0                   0   26     10  2014
# 526913           0                   0                   0   26     10  2014
# 526914           0                   0                   0   26     10  2014
# 526915           0                   0                   0   26     10  2014
# 526916           0                   0                   0   26     10  2014
#
#         holiday_name  around_BlackFriday
# 526912                              Else
# 526913                              Else
# 526914                              Else
# 526915                              Else
# 526916                              Else
#
# [5 rows x 32 columns]

# %%
model2 = sm.OLS.from_formula("units ~ weekday + is_weekend +"
                            "is_holiday +is_holiday_weekend + day +"
                            "year +"
                            "tmin + tavg  + wetbulb + heat+"
                            "cool + sunrise + sunset + snowfall + preciptotal + stnpressure+"
                            "sealevel + resultspeed + resultdir + avgspeed", data=all_data_result)
result = model2.fit()

num_attr = ['store_nbr', 'item_nbr', 'weekday', 'is_weekend', 
            'is_holiday', 'is_holiday_weekend',
            'day', 'year',
            'tmin', 'tavg',
            'wetbulb', 'heat', 'cool', 'sunrise', 'sunset', 'snowfall',
            'preciptotal', 'stnpressure', 'sealevel', 'resultspeed',
            'resultdir', 'avgspeed']

test_predict = test_gg[num_attr]

test = result.predict(test_predict)

# %%
key = pd.read_csv('key.csv')
key
# Out:
#     store_nbr  station_nbr
# 0           1            1
# 1           2           14
# 2           3            7
# 3           4            9
# 4           5           12
# 5           6           14
# 6           7            6
# 7           8            4
# 8           9           17
# 9          10           12
# 10         11           10
# 11         12           11
# 12         13            6
# 13         14           16
# 14         15           13
# 15         16            2
# 16         17           20
# 17         18           17
# 18         19           15
# 19         20            7
# 20         21            3
# 21         22           10
# 22         23           17
# 23         24            9
# 24         25           13
# 25         26           17
# 26         27           10
# 27         28            7
# 28         29            3
# 29         30           19
# 30         31           17
# 31         32           13
# 32         33            3
# ...

# %%
sampleSubmission = pd.read_csv('sampleSubmission.csv')
sampleSubmission
# Out:
#                        id  units
# 0          2_1_2013-04-01      0
# 1          2_2_2013-04-01      0
# 2          2_3_2013-04-01      0
# 3          2_4_2013-04-01      0
# 4          2_5_2013-04-01      0
# 5          2_6_2013-04-01      0
# 6          2_7_2013-04-01      0
# 7          2_8_2013-04-01      0
# 8          2_9_2013-04-01      0
# 9         2_10_2013-04-01      0
# 10        2_11_2013-04-01      0
# 11        2_12_2013-04-01      0
# 12        2_13_2013-04-01      0
# 13        2_14_2013-04-01      0
# 14        2_15_2013-04-01      0
# 15        2_16_2013-04-01      0
# 16        2_17_2013-04-01      0
# 17        2_18_2013-04-01      0
# 18        2_19_2013-04-01      0
# 19        2_20_2013-04-01      0
# 20        2_21_2013-04-01      0
# 21        2_22_2013-04-01      0
# 22        2_23_2013-04-01      0
# 23        2_24_2013-04-01      0
# 24        2_25_2013-04-01      0
# 25        2_26_2013-04-01      0
# 26        2_27_2013-04-01      0
# ...

# %%
test = pd.read_csv('test.csv')
#test1 = test[test["store_nbr"] > 45].sort_values(by=["store_nbr"], ascending=False).reset_index(drop=True)
test.sort_values(by = ['date'], ascending=True)
# Out:
#               date  store_nbr  item_nbr
# 0       2013-04-01          2         1
# 892     2013-04-01         28         5
# 891     2013-04-01         28         4
# 890     2013-04-01         28         3
# 889     2013-04-01         28         2
# 888     2013-04-01         28         1
# 887     2013-04-01         20       111
# 886     2013-04-01         20       110
# 893     2013-04-01         28         6
# 885     2013-04-01         20       109
# 883     2013-04-01         20       107
# 882     2013-04-01         20       106
# 881     2013-04-01         20       105
# 880     2013-04-01         20       104
# 879     2013-04-01         20       103
# 878     2013-04-01         20       102
# 877     2013-04-01         20       101
# 884     2013-04-01         20       108
# 894     2013-04-01         28         7
# 895     2013-04-01         28         8
# 896     2013-04-01         28         9
# 913     2013-04-01         28        26
# ...

# %%
tk = test.merge(key, left_on="store_nbr", right_on="store_nbr")
#tk = tk[tk["store_nbr"] != 2]
tk.tail()
# Out:
#               date  store_nbr  item_nbr  station_nbr
# 526912  2014-08-02         40       107           13
# 526913  2014-08-02         40       108           13
# 526914  2014-08-02         40       109           13
# 526915  2014-08-02         40       110           13
# 526916  2014-08-02         40       111           13

# %%
train = pd.read_csv('train.csv')

train.sort_values(by = ['date'], ascending=False) #4617600
train.tail()
# Out:
#                date  store_nbr  item_nbr  units
# 4617595  2014-10-31         45       107      0
# 4617596  2014-10-31         45       108      0
# 4617597  2014-10-31         45       109      0
# 4617598  2014-10-31         45       110      0
# 4617599  2014-10-31         45       111      0

# %%
rt = train[train["units"] > 0].sort_values(by=["units"], ascending=False).reset_index(drop=True) # 118696
rt

# %%
result = rt.groupby("date").sum()["units"].reset_index() # 날짜별 판매 갯수
result
# Out:
#             date  units
# 0     2012-01-01   6601
# 1     2012-01-02   7802
# 2     2012-01-03   6605
# 3     2012-01-04   5512
# 4     2012-01-05   7533
# 5     2012-01-06   6186
# 6     2012-01-07   7757
# 7     2012-01-08   8329
# 8     2012-01-09   5782
# 9     2012-01-10   6781
# 10    2012-01-11   5317
# 11    2012-01-12   5345
# 12    2012-01-13   5811
# 13    2012-01-14   7423
# 14    2012-01-15   7283
# 15    2012-01-16   5884
# 16    2012-01-17   4776
# 17    2012-01-18   4553
# 18    2012-01-19   4822
# 19    2012-01-20   5070
# 20    2012-01-21   6320
# 21    2012-01-22   7065
# 22    2012-01-23   5413
# 23    2012-01-24   4458
# 24    2012-01-25   4157
# 25    2012-01-26   4507
# 26    2012-01-27   4688
# 27    2012-01-28   6207
# 28    2012-01-29   6749
# 29    2012-01-30   4698
# ...          ...    ...
# 1004  2014-10-02   1968
# 1005  2014-10-03   2730
# 1006  2014-10-04   3126
# 1007  2014-10-05   4477
# 1008  2014-10-06   4282
# 1009  2014-10-07   2863
# ...

# %%
tmpRTResult = result.merge(key, left_on="store_nbr" , right_on="store_nbr")
tmpRTResult
# Out:
#               date  store_nbr  item_nbr  units  station_nbr
# 0       2012-11-15         37         5   5568           13
# 1       2013-11-21         37         5   3369           13
# 2       2014-01-26         37         5    154           13
# 3       2012-04-01         37         5    129           13
# 4       2012-01-21         37         5    127           13
# 5       2012-09-25         37         5    124           13
# 6       2012-02-02         37         5    122           13
# 7       2013-10-20         37         5    122           13
# 8       2012-02-11         37         5    122           13
# 9       2014-01-25         37         5    121           13
# 10      2013-09-22         37         5    120           13
# 11      2012-03-04         37         5    119           13
# 12      2013-02-10         37        45    118           13
# 13      2012-01-07         37         5    112           13
# 14      2012-04-15         37         5    108           13
# ...

# %%
weather = pd.read_csv('weather.csv')
weather["Count"] = 1
weather
# Out:
#        station_nbr        date tmax tmin tavg depart dewpoint wetbulb heat  \
# 0                1  2012-01-01   52   31   42      M       36      40   23
# 1                2  2012-01-01   48   33   41     16       37      39   24
# 2                3  2012-01-01   55   34   45      9       24      36   20
# 3                4  2012-01-01   63   47   55      4       28      43   10
# 4                6  2012-01-01   63   34   49      0       31      43   16
# 5                7  2012-01-01   50   33   42      M       26      35   23
# 6                8  2012-01-01   66   45    M      M       34      46    M
# 7                9  2012-01-01   34   19   27      M       17      23   38
# 8               10  2012-01-01   73   53   63      M       55      58    2
# 9               11  2012-01-01   72   48   60      7       54      56    5
# 10              12  2012-01-01   72   48   60      M       54      57    5
# ...

# %%
#tk = test.merge(key, left_on="store_nbr", right_on="store_nbr")
    
tmpResult = tmpRTResult.merge(w, right_on="station_nbr")
tmpResult
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-0233cd9ce03f> in <module>()
#       1 #tk = test.merge(key, left_on="store_nbr", right_on="store_nbr")
#       2
# ----> 3 tmpResult = tmpRTResult.merge(w, right_on="station_nbr")
#       4 tmpResult
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    5368                      right_on=right_on, left_index=left_index,
#    5369                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 5370                      copy=copy, indicator=indicator, validate=validate)
#    5371
#    5372     def round(self, decimals=0, *args, **kwargs):
#
# ...

# %%
w = pd.DataFrame(weather, columns=["station_nbr", "date", "codesum"])
w
# Out:
#        station_nbr        date         codesum
# 0                1  2012-01-01      RA FZFG BR
# 1                2  2012-01-01              RA
# 2                3  2012-01-01
# 3                4  2012-01-01
# 4                6  2012-01-01
# 5                7  2012-01-01
# 6                8  2012-01-01           RA BR
# 7                9  2012-01-01              UP
# 8               10  2012-01-01       FG+ FG BR
# 9               11  2012-01-01       FG+ FG BR
# 10              12  2012-01-01       FG+ FG BR
# 11              13  2012-01-01
# 12              14  2012-01-01
# 13              15  2012-01-01  RA FG+ FZFG BR
# 14              16  2012-01-01      RA MIFG BR
# 15              17  2012-01-01
# 16              18  2012-01-01
# 17              19  2012-01-01        RA SN BR
# 18              20  2012-01-01
# 19               1  2012-01-02
# 20               2  2012-01-02
# 21               3  2012-01-02
# 22               4  2012-01-02
# ...

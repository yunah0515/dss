# %%
import pandas as pd

# %%
w = pd.read_csv('weather.csv')

# %%
w_codesum = list(w.codesum.unique())
w_codesum
# Out:
# ['RA FZFG BR',
#  'RA',
#  ' ',
#  'RA BR',
#  'UP',
#  'FG+ FG BR',
#  'RA FG+ FZFG BR',
#  'RA MIFG BR',
#  'RA SN BR',
#  'SN UP',
#  'BR',
#  'SN',
#  'BR HZ',
#  'FG+ BR',
#  'SN FG+ FZFG BR',
#  'RA HZ',
#  'RA BR HZ',
#  'FG BR',
#  'TSRA FG+ BR HZ',
#  'RA BR HZ VCTS',
#  'TSRA RA DZ BR',
#  'TSRA RA DZ BR VCTS',
#  'TSRA RA BR',
#  'RA BR VCTS',
#  'SN BR',
#  'TS TSRA RA DZ BR',
#  'SN FZFG BR',
#  'RA SN FG+ FG FZFG BR UP',
#  'SN FZFG BR UP',
#  'DZ SN BR HZ',
#  'RA FZRA FG+ FG BR UP',
#  'FZRA FG+ FZFG UP',
#  'FZRA SN BR UP',
#  'RA FG BR',
#  'SN BR HZ',
#  'RA SN BR HZ',
#  'RA SN FG+ BR',
#  'DZ BR HZ',
#  'RA SN FG BR',
#  'RA SN BR HZ BLSN',
#  'FZDZ BR',
#  'FG+ FG BR HZ',
#  'FG+ FG BCFG BR',
#  'FG+',
#  'SN FZFG',
#  'BR HZ DU',
#  'DZ BR',
#  'BR HZ BLDU',
#  'FG+ BR HZ',
#  'RA FG+ FG BR',
#  'BR HZ DU SQ',
#  'HZ DU',
#  'BR DU',
#  'DZ FZDZ BR',
#  'RA SN FG+ FG BR',
#  'BLDU',
#  'FG+ FG',
#  'DU',
#  'TS RA BR HZ',
#  'BCFG BR',
#  'FG+ FG FZFG BR',
# ...
